# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("social_factors_county.csv")

# %%
data
# Out:
#     state  county  county_population  nursing_home_count  \
# 0      24       1              71977                  16
# 1      24       3             567696                 133
# 2      24       5             827625                 212
# 3      24      15             102517                  24
# 4      24      17             157671                  45
# 5      24      19              32261                   8
# 6      24      21             248472                  31
# 7      24      23              29376                   7
# 8      24      25             251025                  59
# 9      24      27             315327                  88
# 10     24      29              19593                  12
# 11     24      31            1040133                 264
# 12     24      33             906202                 307
# 13     24      37             111531                  10
# 14     24      39              25737                   4
# ...

# %%
value_to_county = {1: 'Allegany', 3: 'Anne Arundel', 5: 'Baltimore county',
                  510: 'Baltimore city', 9: 'Calvert', 11: 'Caroline', 13: "Caroll", 
                  15: 'Cecil', 17: 'Charles', 19: 'Dorchester', 21: 'Frederick', 
                  23: 'Garrett', 25: 'Harford', 27: 'Howard', 29: 'Kent', 31: 'Montgomery', 
                  33: "Prince George's", 35: "Queen Anne's", 39: 'Somerset', 37: "St. Mary's", 
                  41: 'Talbot', 43: 'Washington', 45: 'Wicomico', 47: 'Worcester'}

# %%
for i in range (0, len(data.county)):
    data.county[i] = value_to_county[data.county[i]]
# Out:
# C:\Users\rklau\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\rklau\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
data2 = pd.read_csv("social_factors_hex.csv")

# %%
bools = []
for i in range(0, len(data2)):
    if data2.hexagon_id[i] in ids:
        bools.append(1)
    else:
        bools.append(0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-f40245c5d1d7> in <module>
#       2 for i in range(0, len(data2)):
#       3     if data2.hexagon_id[i] in ids:
# ----> 4         bools.append(1)
#       5     else:
#       6         bools.append(0)
#
# KeyboardInterrupt:

# %%
for i in range (0, len(data2.county)):
    data2.county[i] = value_to_county[data2.county[i]]
# Out:
# C:\Users\rklau\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data2.loc[:2]
# Out:
#      hexagon_id  state    county  economic_risk  food_risk  housing_risk  \
# 0  24001_014561     24  Allegany              1          2             1
# 1  24001_011289     24  Allegany              1          2             1
# 2  24001_008505     24  Allegany              1          1             1
#
#    healthlit_risk  covid_19_ssi  density_inpatient_beds  density_icu_beds  \
# 0               3             3                    43.9              2.08
# 1               4             4                    43.9              2.08
# 2               3             5                    43.9              2.08
#
#    ...  elder_male  teen_female  teen_male  children  pct_snap_utilizers  \
# 0  ...    0.295609     0.070993   0.102416  0.045389            0.170678
# 1  ...    3.197616     0.671822   0.852698  1.195069            0.168088
# 2  ...    1.361055     0.106189   0.088943  0.320187            0.154114
#
#    pct_snap_eligible  pharmacy_idw  provider_idw  percent_low_ed  \
# ...

# %%
data2[data2.covid_19_ssi == 1]
# Out:
#           hexagon_id  state        county  economic_risk  food_risk  \
# 8       24001_004480     24      Allegany              3          3
# 209     24001_004309     24      Allegany              3          3
# 225     24003_074973     24  Anne Arundel              5          4
# 238     24003_016753     24  Anne Arundel              4          4
# 243     24003_076662     24  Anne Arundel              3          5
# ...              ...    ...           ...            ...        ...
# 398385  24047_007570     24     Worcester              3          2
# 398389  24047_010227     24     Worcester              3          2
# 398393  24047_006172     24     Worcester              3          2
# 398410  24047_008481     24     Worcester              3          2
# 398416  24047_015857     24     Worcester              3          4
#
#         housing_risk  healthlit_risk  covid_19_ssi  density_inpatient_beds  \
# ...

# %%
rank1 = data2[data2.covid_19_ssi == 1]
rank2 = data2[data2.covid_19_ssi == 2]
rank3 = data2[data2.covid_19_ssi == 3]
rank4 = data2[data2.covid_19_ssi == 4]
rank5 = data2[data2.covid_19_ssi == 5]

# %%
geom = pd.read_csv("hexagon_geometry.csv")

# %%
ids = [i for i in geom.hexagon_id]

# %%
rank1
# Out:
#           hexagon_id  state        county  economic_risk  food_risk  \
# 8       24001_004480     24      Allegany              3          3
# 209     24001_004309     24      Allegany              3          3
# 225     24003_074973     24  Anne Arundel              5          4
# 238     24003_016753     24  Anne Arundel              4          4
# 243     24003_076662     24  Anne Arundel              3          5
# ...              ...    ...           ...            ...        ...
# 398385  24047_007570     24     Worcester              3          2
# 398389  24047_010227     24     Worcester              3          2
# 398393  24047_006172     24     Worcester              3          2
# 398410  24047_008481     24     Worcester              3          2
# 398416  24047_015857     24     Worcester              3          4
#
#         housing_risk  healthlit_risk  covid_19_ssi  density_inpatient_beds  \
# ...

# %%
data2.head()
# Out:
#      hexagon_id  state    county  economic_risk  food_risk  housing_risk  \
# 0  24001_014561     24  Allegany              1          2             1
# 1  24001_011289     24  Allegany              1          2             1
# 2  24001_008505     24  Allegany              1          1             1
# 3  24001_000961     24  Allegany              2          2             1
# 4  24001_005770     24  Allegany              3          2             1
#
#    healthlit_risk  covid_19_ssi  density_inpatient_beds  density_icu_beds  \
# 0               3             3                    43.9              2.08
# 1               4             4                    43.9              2.08
# 2               3             5                    43.9              2.08
# 3               3             3                    43.9              2.08
# 4               3             2                    43.9              2.08
#
#    ...  elder_male  teen_female  teen_male  children  pct_snap_utilizers  \
# ...

# %%
geom.head()
# Out:
#      hexagon_id  state  county  \
# 0  24019_017327     24      19
# 1  24019_019835     24      19
# 2  24019_020262     24      19
# 3  24019_020270     24      19
# 4  24019_020940     24      19
#
#                                         hex_geometry
# 0  MULTIPOLYGON (((-76.13311864441356 38.35074978...
# 1  MULTIPOLYGON (((-76.10347424003761 38.50863411...
# 2  MULTIPOLYGON (((-76.09723097827252 38.53179783...
# 3  MULTIPOLYGON (((-76.09808434833288 38.46950147...
# 4  MULTIPOLYGON (((-76.08999951077583 38.49273906...

# %%
bools = []
for i in geom.iloc[:,0].isin(list(data2.iloc[:, 0])):
    if i == True:
        bools.append(1)
    else:
        bools.append(0)

# %%
len([i for i in bools if i == 0])
# Out:
# 1689

# %%
bools = []
for i in data2.iloc[:, 0].isin(list(geom.iloc[:,0])):
    if i == True:
        bools.append(1)
    else:
        bools.append(0)

# %%
len([i for i in bools if i == 1])
# Out:
# 398739

# %%
temp = {}
count = 0

for i in geom.iloc[:, 0].isin(list(data2.iloc[:, 0])):
    if i == True:
        temp[geom.iloc[count, 0]] = count
    count += 1
len(temp)
# Out:
# 398739

# %%
temp = geom.iloc[list(temp.values()), :]

# %%
final = geom.sort_values(by = ['hexagon_id'])

# %%
social_ssi = [int(i) for i in data2.covid_19_ssi]

# %%
temp['covid_19_ssi'] = social_ssi
# Out:
# C:\Users\rklau\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final = temp

# %%
final
# Out:
#           hexagon_id  state  county  \
# 0       24019_017327     24      19
# 1       24019_019835     24      19
# 2391    24019_020262     24      19
# 3       24019_020270     24      19
# 4       24019_020940     24      19
# ...              ...    ...     ...
# 480462  24031_084579     24      31
# 480463  24031_084580     24      31
# 480464  24031_084585     24      31
# 480465  24031_084586     24      31
# 480466  24031_084589     24      31
#
#                                              hex_geometry  covid_19_ssi
# 0       MULTIPOLYGON (((-76.13311864441356 38.35074978...             3
# 1       MULTIPOLYGON (((-76.10347424003761 38.50863411...             4
# 2391    MULTIPOLYGON (((-76.09808434833288 38.53063680...             5
# 3       MULTIPOLYGON (((-76.09808434833288 38.46950147...             3
# 4       MULTIPOLYGON (((-76.08999951077583 38.49273906...             2
# ...                                                   ...           ...
# ...

# %%
final1 = final[final['covid_19_ssi'] == 1]
final2 = final[final['covid_19_ssi'] == 2]
final3 = final[final['covid_19_ssi'] == 3]
final4 = final[final['covid_19_ssi'] == 4]
final5 = final[final['covid_19_ssi'] == 5]

# %%
final1.to_csv('final1.csv')

# %%
final2.to_csv('final2.csv')
final3.to_csv('final3.csv')
final4.to_csv('final4.csv')
final5.to_csv('final5.csv')
